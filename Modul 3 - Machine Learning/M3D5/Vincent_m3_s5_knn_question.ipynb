# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## **EXERCISE: KNN**
#
# **Gunakan dataset 'cancer'**
#
# - Pada latihan ini, kita sebagai data scientist di bidang kedokteran diminta untuk menentukan apakah sebuah tumor merupakan kanker ganas (malignant) atau jinak (benign)
#
# - Untuk simplifikasi, kita hanya akan menggunakan 2 feature:
#     - Features: 'texture_mean' dan 'concave points_mean'
#     - Target: 'diagnosis'
# <br><br>
#
# - Buat kolom baru yang berasal dari kololm diagnosis. Ubah dari string menjadi integer
#     - malignant --> 1
#     - benign --> 0
# <br><br>
#
# - Lakukan splitting pada dataset dengan:
#     - 20% test set
#     - random_state = 42
# <br><br>
#
# - Lakukan modeling dengan KNN
# - Temukan nilai K terbaik untuk model KNN, lalu gunakan metriks accuracy untuk mengevaluasi performa model antara KNN tanpa dan dengan scaling (MinMaxScaler).
#
# **Informasi terkait dataset dapat dilihat pada link berikut:**
#
# <https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)>
# **atau**
# <https://www.kaggle.com/uciml/breast-cancer-wisconsin-data>

# %%
df = pd.read_csv('cancer_data.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
# 2    94.03       0.006150         0.04006       0.03832            0.02058
# 3    27.23       0.009110         0.07458       0.05661            0.01867
# 4    94.44       0.011490         0.02461       0.05688            0.01885
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
# 2      0.02250              0.004571         23.57          25.53
# 3      0.05963              0.009208         14.91          26.50
# 4      0.01756              0.005115         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN

# %%
df[['diagnosis','texture_mean','concave points_mean']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   diagnosis            569 non-null    object
#  1   texture_mean         569 non-null    float64
#  2   concave points_mean  569 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 13.5+ KB

# %%
df[['diagnosis','texture_mean','concave points_mean']].isna().sum()
# Out:
# diagnosis              0
# texture_mean           0
# concave points_mean    0
# dtype: int64

# %%
df[['diagnosis','texture_mean','concave points_mean']].duplicated().sum()
# Out:
# 0

# %%
dfo = df[['diagnosis','texture_mean','concave points_mean']].copy()

for column in dfo.columns:
    if pd.api.types.is_numeric_dtype(dfo[column]):
        Q1 = dfo[column].quantile(0.25)
        Q3 = dfo[column].quantile(0.75)
        IQR = Q3 - Q1     
        outliers = (dfo[column] < Q1 - 1.5 * IQR) | (dfo[column] > Q3 + 1.5 * IQR)
        dfo = dfo[~outliers]
    else:
        pass

dfo.head()
# Out:
#   diagnosis  texture_mean  concave points_mean
# 0         M         10.38              0.14710
# 1         M         17.77              0.07017
# 2         M         21.25              0.12790
# 3         M         20.38              0.10520
# 4         M         14.34              0.10430

# %%
dfo['diagnosis'].value_counts()
# Out:
# diagnosis
# B    355
# M    196
# Name: count, dtype: int64

# %%
dfo['diagnosis']=dfo['diagnosis'].map({'M':1,'B':0})
dfo.head()
# Out:
#    diagnosis  texture_mean  concave points_mean
# 0          1         10.38              0.14710
# 1          1         17.77              0.07017
# 2          1         21.25              0.12790
# 3          1         20.38              0.10520
# 4          1         14.34              0.10430

# %% [markdown]
# # EDA

# %%
Y = dfo['diagnosis']
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
X = dfo.drop(columns=['diagnosis'])
X
# Out:
#      texture_mean  concave points_mean
# 0           10.38              0.14710
# 1           17.77              0.07017
# 2           21.25              0.12790
# 3           20.38              0.10520
# 4           14.34              0.10430
# ..            ...                  ...
# 563         25.09              0.14740
# 564         22.39              0.13890
# 565         28.25              0.09791
# 566         28.08              0.05302
# 568         24.54              0.00000
#
# [551 rows x 2 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)
display(X_train, X_test, Y_train, Y_test)
# Out:
#      texture_mean  concave points_mean
# 541         24.99             0.038900
# 213         25.56             0.065970
# 211         18.94             0.013930
# 52          18.24             0.013490
# 316         14.08             0.005051
# ..            ...                  ...
# 389         23.21             0.102100
# 101         13.43             0.000000
# 174         15.15             0.000000
# 254         19.33             0.085910
# 520         13.90             0.024210
#
# [440 rows x 2 columns]
#      texture_mean  concave points_mean
# 7           20.83              0.05985
# 71          14.64              0.02872
# 295         13.27              0.01917
# 568         24.54              0.00000
# 244         23.50              0.08886
# ..            ...                  ...
# 515         18.61              0.02594
# 105         15.56              0.09601
# 208         22.54              0.05102
# 538         25.49              0.00000
# 222         17.53              0.01915
#
# [111 rows x 2 columns]
# 541    0
# 213    1
# 211    0
# 52     0
# 316    0
#       ..
# 389    1
# 101    0
# 174    0
# 254    1
# 520    0
# Name: diagnosis, Length: 440, dtype: int64
# 7      1
# 71     0
# 295    0
# 568    0
# 244    1
#       ..
# 515    0
# 105    1
# 208    0
# 538    0
# 222    0
# Name: diagnosis, Length: 111, dtype: int64

# %% [markdown]
# # Modeling and Accuracy without Scaling

# %%
df_acc = pd.DataFrame(columns=['k','accuracy'])

for i in range (1,221,2):
    model_knn = KNeighborsClassifier(n_neighbors=i).fit(X_train,Y_train)
    Y_predict = model_knn.predict(X_test)
    df_acc.loc[len(df_acc)] = {'k': i, 'accuracy': accuracy_score(Y_test, Y_predict)}

print(df_acc[df_acc['accuracy']==df_acc['accuracy'].max()])
sns.lineplot(data=df_acc, x='k', y='accuracy')
plt.show()
# Out:
#    k  accuracy
# 0  1   0.81982

# %% [markdown]
# # Modeling and Accuracy with Scaling

# %%
X_train = MinMaxScaler().fit(X_train).transform(X_train)
X_test = MinMaxScaler().fit(X_test).transform(X_test)
display(X_train,X_test)
# Out:
# array([[0.75419546, 0.25864362],
#        [0.78232971, 0.43863032],
#        [0.45557749, 0.09261968],
#        [0.42102665, 0.08969415],
#        [0.21569595, 0.03358378],
#        [0.74925962, 0.28417553],
#        [0.44619941, 0.20957447],
#        [0.40572557, 0.03718085],
#        [0.90572557, 0.21775266],
#        [0.59279368, 0.37220745],
#        [0.45014808, 0.42333777],
#        [0.3094768 , 0.19574468],
#        [0.54244817, 0.14414894],
#        [0.29072063, 0.24807181],
#        [0.43139191, 0.13756649],
#        [0.41806515, 0.36994681],
#        [0.38746298, 0.29521277],
#        [0.48371175, 0.61130319],
#        [0.88005923, 0.48962766],
#        [0.03307009, 0.97805851],
#        [0.46051333, 0.14827128],
#        [0.04985192, 0.05922207],
#        [0.5834156 , 0.13351064],
#        [0.60217177, 0.45525266],
#        [0.45952616, 0.05674867],
#        [0.36080948, 0.16329787],
#        [0.5266535 , 0.69946809],
#        [0.62586377, 0.92353723],
#        [0.34106614, 0.09109043],
#        [0.58538993, 0.16117021],
#        [0.        , 0.11289894],
#        [0.37265548, 0.10890957],
#        [0.30157947, 0.02168218],
#        [0.53553801, 0.51609043],
#        [0.36377098, 0.55538564],
#        [0.34402764, 0.27121011],
#        [0.49062192, 0.51848404],
#        [0.58390918, 0.37320479],
#        [0.69595262, 0.42965426],
#        [0.41016782, 0.13477394],
#        [0.54639684, 0.17586436],
#        [0.8183613 , 0.97672872],
#        [0.72951629, 0.08730053],
#        [0.22951629, 0.31788564],
#        [0.43830207, 0.37253989],
#        [0.7290227 , 0.31542553],
#        [0.37462981, 0.14009309],
#        [0.60562685, 0.09335106],
#        [0.85735439, 0.02077793],
#        [0.35192498, 0.15239362],
#        [0.23395854, 0.        ],
#        [0.2230997 , 0.13949468],
#        [0.59674235, 0.24900266],
#        [0.38795656, 0.57340426],
#        [0.31885489, 0.20824468],
#        [0.49901283, 0.64760638],
#        [0.51431392, 0.34966755],
#        [0.33464956, 0.19042553],
#        [0.31786772, 0.71808511],
#        [0.33020731, 0.93151596],
#        [0.30750247, 0.64275266],
#        [0.10266535, 0.05185505],
#        [0.40128332, 0.08231383],
#        [0.1727542 , 0.17666223],
#        [0.60760118, 0.22167553],
#        [0.13474827, 0.13803191],
#        [0.50691017, 0.49202128],
#        [0.38252715, 0.27147606],
#        [0.66041461, 0.12466755],
#        [0.488154  , 0.15246011],
#        [0.17028628, 0.17041223],
#        [0.70730503, 0.56801862],
#        [0.31145114, 0.22406915],
#        [0.32625864, 0.21801862],
#        [0.40918065, 0.15392287],
#        [0.41609082, 0.23371011],
#        [0.32082922, 0.13882979],
#        [0.15399803, 0.07639628],
#        [0.38252715, 0.15159574],
#        [0.21618954, 0.16848404],
#        [0.70631787, 0.19660904],
#        [0.58687068, 0.97805851],
#        [0.77541955, 0.2012633 ],
#        [0.85192498, 0.8224734 ],
#        [0.18065153, 0.16941489],
#        [0.34501481, 0.19913564],
#        [0.54146101, 0.68351064],
#        [0.38598223, 0.11801862],
#        [0.26604146, 0.83444149],
#        [0.41164857, 0.39514628],
#        [0.52319842, 0.3450133 ],
#        [0.59180652, 0.08357713],
#        [0.10760118, 0.7293883 ],
#        [0.6130306 , 0.49913564],
#        [0.4165844 , 0.85505319],
#        [0.23346496, 0.1724734 ],
#        [0.38548865, 0.61057181],
#        [0.45310958, 0.35777926],
#        [0.41707799, 0.09986702],
#        [0.91510365, 0.65099734],
#        [0.46248766, 0.72473404],
#        [0.91312932, 0.07426862],
#        [0.470385  , 0.13763298],
#        [0.2917078 , 0.10445479],
#        [0.25419546, 0.30106383],
#        [0.41806515, 0.62925532],
#        [0.54442251, 0.70079787],
#        [0.54294176, 0.5643617 ],
#        [0.40621915, 0.1549867 ],
#        [0.50641658, 0.60591755],
#        [0.51431392, 0.18836436],
#        [0.43484699, 0.58477394],
#        [0.12635735, 0.17599734],
#        [0.59871668, 0.38417553],
#        [0.5745311 , 0.37692819],
#        [0.35241856, 0.18557181],
#        [0.46051333, 0.09494681],
#        [0.12388944, 0.13085106],
#        [0.58687068, 0.07413564],
#        [0.75370188, 0.29847074],
#        [0.42892399, 0.01944149],
#        [0.27147088, 0.1125    ],
#        [0.41411649, 0.03835771],
#        [0.86080948, 0.42759309],
#        [0.25913129, 0.22214096],
#        [0.50987167, 0.14401596],
#        [0.79121422, 0.43570479],
#        [0.2946693 , 0.1606383 ],
#        [0.36870681, 0.21615691],
#        [0.50098717, 0.05041888],
#        [0.5834156 , 0.58397606],
#        [0.16732478, 0.10039894],
#        [0.89684107, 0.        ],
#        [0.37314906, 0.82579787],
#        [0.84501481, 0.84109043],
#        [0.21076012, 0.4318484 ],
#        [0.50839092, 0.37207447],
#        [0.77541955, 0.38138298],
#        [0.28035538, 0.19115691],
#        [0.49457058, 0.43896277],
#        [0.29565647, 0.22539894],
#        [0.27295163, 0.46968085],
#        [0.45360316, 0.32632979],
#        [0.65745311, 0.57732713],
#        [0.37314906, 0.12978723],
#        [0.49605133, 0.12892287],
#        [0.7023692 , 0.60033245],
#        [0.56564659, 0.14488032],
#        [0.29565647, 0.30339096],
#        [0.45360316, 0.70611702],
#        [0.32675222, 0.15804521],
#        [0.2082922 , 0.39448138],
#        [0.53455084, 0.08351064],
#        [0.53405726, 0.20332447],
#        [0.13030602, 0.09102394],
#        [0.61747285, 0.01231383],
#        [0.16436328, 0.18317819],
#        [0.74531096, 0.66230053],
#        [0.14955577, 0.13051862],
#        [0.96643633, 0.13410904],
#        [0.4047384 , 0.08836436],
#        [0.45310958, 0.14448138],
#        [0.35636723, 0.3724734 ],
#        [0.40375123, 0.43922872],
#        [0.53356367, 0.76795213],
#        [0.43879566, 0.        ],
#        [0.57847976, 0.40492021],
#        [0.34106614, 0.08902926],
#        [0.70286278, 0.56648936],
#        [0.61204344, 0.25771277],
#        [0.29417572, 0.09355053],
#        [0.56959526, 0.85039894],
#        [0.43928924, 0.11835106],
#        [0.24580454, 0.17546543],
#        [0.75913129, 0.98005319],
#        [0.42349457, 0.12519947],
#        [0.65794669, 0.57393617],
#        [0.48617966, 0.27307181],
#        [0.25765054, 0.13789894],
#        [0.67028628, 0.35046543],
#        [0.16633761, 0.11875   ],
#        [0.26999013, 0.24674202],
#        [0.65153011, 0.63025266],
#        [0.26011846, 0.1474734 ],
#        [0.57107601, 0.03430186],
#        [0.47729516, 0.18929521],
#        [0.33909181, 0.16210106],
#        [0.52171767, 0.40944149],
#        [0.59871668, 0.14242021],
#        [0.3751234 , 0.1237367 ],
#        [0.41757157, 0.33736702],
#        [0.39536032, 0.22114362],
#        [0.51332675, 0.58949468],
#        [0.32082922, 0.10738032],
#        [0.15794669, 0.20990691],
#        [0.5774926 , 0.19042553],
#        [0.44866732, 0.43723404],
#        [0.62142152, 0.225     ],
#        [0.60858835, 0.64507979],
#        [0.91411649, 0.12932181],
#        [0.47433366, 0.49787234],
#        [0.30552813, 0.1099734 ],
#        [0.517769  , 0.15339096],
#        [0.66781836, 0.22094415],
#        [0.66584403, 0.91555851],
#        [0.0774926 , 0.41296543],
#        [0.85636723, 0.62054521],
#        [0.51826259, 0.32918883],
#        [0.3035538 , 0.46456117],
#        [0.34353406, 0.17287234],
#        [0.89536032, 0.29308511],
#        [0.62092794, 0.43390957],
#        [0.3183613 , 0.0565625 ],
#        [0.72951629, 0.4494016 ],
#        [0.28331688, 0.21609043],
#        [0.21470879, 0.35013298],
#        [0.47581441, 0.19614362],
#        [0.52714709, 0.190625  ],
#        [0.20483712, 0.14494681],
#        [0.57551826, 0.12413564],
#        [0.05923001, 0.11941489],
#        [0.71865745, 0.9375    ],
#        [0.77640671, 0.09069149],
#        [0.54540967, 0.25206117],
#        [0.16041461, 0.04380319],
#        [0.26653504, 0.01598404],
#        [0.27788746, 0.52240691],
#        [0.89338598, 0.55452128],
#        [0.25024679, 0.01955452],
#        [0.14807502, 0.02938165],
#        [0.5088845 , 0.14341755],
#        [0.41263574, 0.03623005],
#        [0.36969398, 0.24022606],
#        [0.53356367, 0.11768617],
#        [0.55034551, 0.87898936],
#        [0.66189536, 0.4400266 ],
#        [0.66732478, 0.16243351],
#        [0.24925962, 0.17606383],
#        [0.25863771, 0.13656915],
#        [0.39239882, 0.15026596],
#        [0.42003949, 0.        ],
#        [0.42991115, 0.1943484 ],
#        [0.59081935, 0.73337766],
#        [0.43879566, 0.25405585],
#        [0.12142152, 0.15970745],
#        [0.54096742, 0.67486702],
#        [0.23149062, 0.02308511],
#        [0.62981244, 0.17978723],
#        [0.55577493, 0.14847074],
#        [0.31145114, 0.29900266],
#        [0.4911155 , 0.51369681],
#        [0.35686081, 0.19128989],
#        [0.46939783, 0.82579787],
#        [0.8272458 , 0.50485372],
#        [0.40523198, 0.17639628],
#        [0.66633761, 0.67885638],
#        [0.18361303, 0.        ],
#        [0.26850938, 0.        ],
#        [0.47482725, 0.57121011],
#        [0.20681145, 0.16097074]])
# array([[0.53962264, 0.39873418],
#        [0.20592992, 0.19133911],
#        [0.13207547, 0.12771486],
#        [0.73962264, 0.        ],
#        [0.68355795, 0.59200533],
#        [0.26792453, 0.06620253],
#        [0.26307278, 0.5389074 ],
#        [0.70188679, 0.45789474],
#        [0.57088949, 0.07168554],
#        [0.30134771, 0.32285143],
#        [0.43126685, 0.79546969],
#        [0.59622642, 0.53171219],
#        [0.44690027, 0.07648235],
#        [0.64366577, 0.49853431],
#        [0.26361186, 0.2071952 ],
#        [0.33045822, 0.25189873],
#        [0.33315364, 0.11319121],
#        [0.30727763, 0.15136576],
#        [0.53908356, 0.36235843],
#        [0.        , 0.17475017],
#        [0.45929919, 0.19487009],
#        [0.25283019, 0.46908728],
#        [0.24366577, 0.2320453 ],
#        [0.53584906, 0.40113258],
#        [0.53477089, 0.2338441 ],
#        [0.74770889, 0.20552965],
#        [0.62911051, 0.45116589],
#        [0.406469  , 0.11838774],
#        [0.28086253, 0.15469687],
#        [0.69703504, 0.61132578],
#        [0.77789757, 0.13777482],
#        [0.12075472, 0.08860759],
#        [0.59730458, 1.        ],
#        [0.18975741, 0.69487009],
#        [0.43557951, 0.05654897],
#        [0.36981132, 0.18647568],
#        [0.63557951, 0.53464357],
#        [0.13854447, 0.31952032],
#        [0.77142857, 0.11738841],
#        [0.26630728, 0.15376416],
#        [0.45929919, 0.0640573 ],
#        [0.57789757, 0.15896069],
#        [0.57897574, 0.57901399],
#        [0.32506739, 0.41665556],
#        [0.65983827, 0.18900733],
#        [0.21886792, 0.0859427 ],
#        [0.21132075, 0.2350433 ],
#        [0.26792453, 0.33770819],
#        [0.59946092, 0.08540973],
#        [0.36927224, 0.12225183],
#        [0.58544474, 0.03416389],
#        [0.39622642, 0.09153897],
#        [0.12668464, 0.4407062 ],
#        [0.33962264, 0.28434377],
#        [0.86469003, 0.30393071],
#        [0.47277628, 0.07435043],
#        [0.32345013, 0.04163891],
#        [0.41832884, 0.38734177],
#        [0.33692722, 0.07741506],
#        [0.58059299, 0.54117255],
#        [0.29811321, 0.03660893],
#        [0.26091644, 0.17668221],
#        [0.32398922, 0.16522318],
#        [1.        , 0.        ],
#        [0.16603774, 0.29653564],
#        [0.3541779 , 0.10346436],
#        [0.22318059, 0.11905396],
#        [0.15633423, 0.19080613],
#        [0.10889488, 0.22318454],
#        [0.13315364, 0.19200533],
#        [0.16280323, 0.05882079],
#        [0.32506739, 0.04279147],
#        [0.48571429, 0.66822119],
#        [0.00377358, 0.38494337],
#        [0.57358491, 0.32898068],
#        [0.47493261, 0.2290473 ],
#        [0.30026954, 0.5685543 ],
#        [0.88032345, 0.28674217],
#        [0.50673854, 0.3958028 ],
#        [0.76442049, 0.60379747],
#        [0.34447439, 0.07601599],
#        [0.54878706, 0.66182545],
#        [0.63234501, 0.408994  ],
#        [0.64150943, 0.19840107],
#        [0.1703504 , 0.41972019],
#        [0.47601078, 0.44223851],
#        [0.31536388, 0.59447035],
#        [0.22102426, 0.15729514],
#        [0.48247978, 0.38900733],
#        [0.25229111, 0.18367755],
#        [0.40269542, 0.32211859],
#        [0.40592992, 0.20932712],
#        [0.59083558, 0.51865423],
#        [0.56549865, 0.52971352],
#        [0.18544474, 0.64996669],
#        [0.28301887, 0.13530979],
#        [0.35633423, 0.07361759],
#        [0.11105121, 0.18207861],
#        [0.41347709, 0.10086609],
#        [0.12506739, 0.46888741],
#        [0.38059299, 0.5164557 ],
#        [0.5083558 , 0.43051299],
#        [0.18005391, 0.0222052 ],
#        [0.14123989, 0.18640906],
#        [0.68679245, 0.8727515 ],
#        [0.50889488, 0.35909394],
#        [0.41994609, 0.17281812],
#        [0.25552561, 0.63964024],
#        [0.63180593, 0.33990673],
#        [0.79083558, 0.        ],
#        [0.36172507, 0.12758161]])

# %%
df_acc = pd.DataFrame(columns=['k','accuracy'])

for i in range (1,len(Y_train),2):
    model_knn = KNeighborsClassifier(n_neighbors=i).fit(X_train,Y_train)
    Y_predict = model_knn.predict(X_test)
    df_acc.loc[len(df_acc)] = {'k': i, 'accuracy': accuracy_score(Y_test, Y_predict)}

print(df_acc[df_acc['accuracy']==df_acc['accuracy'].max()])
sns.lineplot(data=df_acc, x='k', y='accuracy')
plt.show()
# Out:
#      k  accuracy
# 5   11   0.90991
# 14  29   0.90991
# 15  31   0.90991

# %%
model_knn = KNeighborsClassifier(n_neighbors=11).fit(X_train,Y_train)
Y_predict = model_knn.predict(X_test)
print(f'Nilai k terbaik didapatkan ketika dilakukan scaling terlebih dahulu dengan nilai k=11 dan akurasinya {round(accuracy_score(Y_test, Y_predict)*100)} %')
# Out:
# Nilai k terbaik didapatkan ketika dilakukan scaling terlebih dahulu dengan nilai k=11 dan akurasinya 91 %
